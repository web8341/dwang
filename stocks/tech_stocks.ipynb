# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from datetime import datetime

# %% [markdown]
# #from pandas_datareader import data, wb ##it is not working.And different source has didderent import mathod

# %%
 import pandas.io.data as wb
# Out:
# C:\Users\woowoo\Anaconda3\lib\site-packages\pandas\io\data.py:33: FutureWarning:
# The pandas.io.data module is moved to a separate package (pandas-datareader) and will be removed from pandas in a future version.
# After installing the pandas-datareader package (https://github.com/pydata/pandas-datareader), you can change the import ``from pandas.io import data, wb`` to ``from pandas_datareader import data, wb``.
#   FutureWarning)

# %%
tech_list = ['AAPL','GOOG','MSFT','AMZN']

# %%
end = datetime.now()
start = datetime(end.year-1,end.month,end.day)

# %%
for stock in tech_list:
    globals()[stock] = wb.DataReader(stock, 'yahoo', start, end)

# %%
GOOG.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2015-02-17  546.832511  550.002460  541.092465  542.842504  1616800
# 2015-02-18  541.402458  545.492471  537.512456  539.702422  1453100
# 2015-02-19  538.042413  543.112470  538.012424  542.872432   989100
# 2015-02-20  543.132484  543.752470  535.802444  538.952441  1444400
# 2015-02-23  536.052398  536.441465  529.412361  531.912381  1457900
#
#              Adj Close
# Date
# 2015-02-17  542.842504
# 2015-02-18  539.702422
# 2015-02-19  542.872432
# 2015-02-20  538.952441
# 2015-02-23  531.912381

# %%
AAPL.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  251.000000  251.000000  251.000000  251.000000  2.510000e+02
# mean   118.235458  119.313586  116.915538  118.093107  5.140983e+07
# std     10.424933   10.231906   10.605928   10.401079  2.073201e+07
# min     93.129997   94.500000   92.000000   93.419998  1.304640e+07
# 25%    111.785000  112.765000  110.075001  111.990002  3.734320e+07
# 50%    119.209999  119.989998  117.919998  119.300003  4.688620e+07
# 75%    127.075001  127.934998  125.985000  126.880001  5.901405e+07
# max    134.460007  134.539993  131.399994  133.000000  1.622063e+08
#
#         Adj Close
# count  251.000000
# mean   116.707367
# std      9.819636
# min     92.915814
# 25%    110.910835
# 50%    118.377140
# 75%    124.815072
# max    130.671320

# %%
AAPL['Adj Close'].plot(legend=True,figsize=(10,4))

# %%
AAPL['Volume'].plot(legend=True,figsize=(10,4))

# %%
ma_days = [10,20,55]
